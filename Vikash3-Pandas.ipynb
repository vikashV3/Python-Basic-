# %%
import pandas as pd

# %%
newdata = {
    'apple': [12,34,56,78,90,0],
    'test' : [0,1,2,3,4,5]
    
}

ok = pd.DataFrame(newdata)
ok.iloc[[1,3,5]]
# Out:
#    apple  test
# 1     34     1
# 3     78     3
# 5      0     5

# %%
thisdata.loc['2']
# Out:
# apple    56
# test      2
# Name: 2, dtype: int64

# %%
testdata={
    'Complex':[0j,1,2,3,4+4j],
    'Float':[01.122,31,5,5454,0],
    "Integear":[0,1,2,3,4],
    'String':["string",1.01,1,1j,"string"]
}

data=pd.DataFrame(testdata , index=['First','Sec','Third','4th','5'])
data
# Out:
#        Complex     Float  Integear  String
# First       0j     1.122         0  string
# Sec     (1+0j)    31.000         1    1.01
# Third   (2+0j)     5.000         2       1
# 4th     (3+0j)  5454.000         3      1j
# 5       (4+4j)     0.000         4  string

# %%
data.loc['Sec']
# Out:
# Complex     (1+0j)
# Float           31
# Integear         1
# String        1.01
# Name: Sec, dtype: object

# %%
df = pd.read_csv('C:/Users/mishr/Desktop/Book1.csv')
df
# Out:
#    SALE Year
# 0  2000  jan
# 1   300  may
# 2   400  feb

# %%
df = pd.read_csv('C:/Users/mishr/Desktop/book1.csv')
condition=(df[['SALE']]=='300')
condition
# Out:
#     SALE
# 0  False
# 1  False
# 2  False

# %%
df = pd.read_csv('c:/Users/mishr/Desktop/Financial Distress.csv')
df.drop_duplicates()
df
# Out:
#       Company  Time  Financial Distress        x1        x2        x3  \
# 0           1     1            0.010636   1.28100  0.022934  0.874540
# 1           1     2           -0.455970   1.27000  0.006454  0.820670
# 2           1     3           -0.325390   1.05290 -0.059379  0.922420
# 3           1     4           -0.566570   1.11310 -0.015229  0.858880
# 4           2     1            1.357300   1.06230  0.107020  0.814600
# 5           2     2            0.007188   1.05580  0.081916  0.879490
# 6           2     3            1.200200   0.97059  0.076064  0.906770
# 7           2     4            2.234800   1.05900  0.130200  0.818110
# 8           2     5            1.340500   1.12450  0.147840  0.758710
# 9           2     6            2.047400   1.59980  0.262460  0.546150
# 10          2     7            2.345900   1.57560  0.262100  0.564480
# 11          2     8            2.249900   1.54430  0.240910  0.590730
# ...

# %%
df=pd.read_csv("C:/Users/mishr/Desktop/oneyear.csv")

df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-b2bbc7cc5e5e> in <module>
#       1 df=pd.read_csv("C:/Users/mishr/Desktop/oneyear.csv")
#       2
# ----> 3 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df=pd.read_csv('C:/Users/mishr/Desktop/test.csv',index_col=2)

df
# Out:
#            TEST1  lowercasr  test
# UPPERCASE
# 3              1          2     4
# 7              5         65     8
# 0              9          0    75

# %% [markdown]
# df=pd.read_csv('C:/Users/mishr/Desktop/test.csv',index_col=1)
#
# df

# %%
df=pd.read_csv('C:/Users/mishr/Desktop/test.csv')
df
# Out:
#    TEST1  lowercasr  UPPERCASE  test
# 0      1          2          3     4
# 1      5         65          7     8
# 2      9          0          0    75

# %%
test=pd.read_csv('C:/Users/mishr/Desktop/test.csv',index_col=0)
test1=test.iloc[]
test1
# Out:
# lowercase    65
# UPPERCASE     7
# test          8
# Name: 5, dtype: int64

# %%
test=pd.read_json('C:/Users/mishr/Desktop/world-countries.json')

test1=pd.read_csv('C:/Users/mishr/Desktop/Book1.csv')
test1
# Out:
#    SALE Year
# 0  2000  jan
# 1   300  may
# 2   400  feb

# %%
import pandas as pd
df = pd.read_csv('C:/Users/mishr/Desktop/Book1.csv',index_col=0)
df
# Out:
#      Year
# SALE
# 2000  jan
# 300   may
# 400   feb

# %%
# Out:
#       name  score
# 1     Dima    9.0
# 3    James    0.0
# 5  Michael   20.0
# 6  Matthew   14.5

# %%
nan=0
data = {
    'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
    'score': [12.5, 9, 16.5,nan, 9, 20, 14.5, nan, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']
}
test=pd.DataFrame(data , index = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'] )

test1=test[['name','score']]
test1[(test1['name']=='Anastasia')&(test1['name']=='Emily')&(test1['name']=='Michael')]
test1
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    0.0
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura    0.0
# i      Kevin    8.0
# j      Jonas   19.0
