# %%
import pandas as pd

# %%
nan=0
data = {
    'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
    'score': [12.5, 9, 16.5,nan, 9, 20, 14.5, nan, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']
}

test=pd.DataFrame(data , index = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'] )
test1=test.loc[['a','b','c']]
test2=test1[['name','score']]
test2
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5

# %%
import pandas as pd
data = {
    'X':[78,85,96,80,86],
    'Y':[84,94,89,83,86],
    'Z':[86,97,96,72,83]
}
data1=pd.DataFrame(data , index=['A','B','C','E',"F"])

test=data1.loc[['A','B']]
test1=test[['X','Y']]
test2=test1[test1['X']>80]
test3=test2[['X']]
test3
# Out:
#     X
# B  85

# %%
# Out:
#     X   Y
# B  85  94

# %%
data1 = {
    'X':[78,85,96],
    'Y':[84,94,89],
    'Z':[86,97,96]
}

testdata=pd.DataFrame(data1 , index=['A','B','C'])

testdata1=(testdata['X']==85)
testdata1
# Out:
# A    False
# B     True
# C    False
# Name: X, dtype: bool

# %%
nan=0
data = {
    'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
    'score': [12.5, 9, 16.5,nan, 9, 20, 14.5, nan, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']
}

test=pd.DataFrame(data , index = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])

test1=(test['attempts']>2)
test1
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f     True
# g    False
# h    False
# i    False
# j    False
# Name: attempts, dtype: bool

# %%
import pandas as pd
nan=0
data = {
    'name': ['Anastasia', 'Dima','Katherine' , 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
    'score': [12.5, 9, 16.5,nan, 9, 20, 14.5, nan, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']
}

test=pd.DataFrame(data , index = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])

test1=test[['name','score']]
test2=test.iloc[['a','b','c']]
test2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-e4aa7d855d09> in <module>
#      11
#      12 test1=test[['name','score']]
# ---> 13 test2=test.iloc[['a','b','c']]
#      14 test2
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2219         # a list of integers
#    2220         elif is_list_like_indexer(key):
# -> 2221             return self._get_list_axis(key, axis=axis)
#    2222
#    2223         # a single integer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_list_axis(self, key, axis)
# ...

# %%
import pandas as pd
nan=0
data = {
    'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
    'score': [12.5, 9, 16.5,nan, 9, 20, 14.5, nan, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']
}

test=pd.DataFrame(data , index = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])

test1=test[['name']]
test2=test1.iloc[[0,1]]
test2
# Out:
#         name
# a  Anastasia
# b       Dima

# %%
newdataframe=pd.read_csv('C:/Users/mishr/Desktop/oneyear.csv')
newdataframe.tail(15)
newdataframe
# Out:
#                           time  latitude  longitude   depth  mag magType  nst  \
# 0     2018-02-10T05:12:35.460Z    5.1033   125.3179   44.32  4.3      mb  NaN
# 1     2018-02-10T00:31:19.880Z   -8.8535   117.1527  116.88  4.9      mb  NaN
# 2     2018-02-08T09:52:47.330Z    4.7512    96.2239   10.00  5.3     mww  NaN
# 3     2018-02-07T22:28:37.900Z  -10.1202   118.7274   10.00  4.5      mb  NaN
# 4     2018-02-07T20:22:57.530Z    1.4361   127.0142  120.78  4.5      mb  NaN
# 5     2018-02-06T07:16:48.280Z    0.6058   126.2786   40.52  4.4      mb  NaN
# 6     2018-02-04T19:55:05.120Z   -9.1216   122.4742  142.29  5.2     mww  NaN
# 7     2018-02-03T23:23:52.510Z   -1.3392    99.6884   45.74  4.7      mb  NaN
# 8     2018-02-03T22:50:44.200Z    1.0990    98.9888  106.01  4.2      mb  NaN
# 9     2018-02-03T18:28:58.520Z    7.1680   126.6065   76.31  4.7      mb  NaN
# 10    2018-02-03T13:37:00.240Z   -7.5370   127.7248  148.79  4.9      mb  NaN
# ...

# %%
nan=0
data = {
    'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
    'score': [12.5, 9, 16.5,nan, 9, 20, 14.5, nan, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']
}

test=pd.DataFrame(data , index = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'] )
test1=test.loc[['a','b','c']]
test2=test1[['name','score']]
test2.shape
# Out:
# (3, 2)
